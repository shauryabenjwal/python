# %% [markdown]
# # Name: Shaurya benjwal
# # SAP ID: 590028986

# %% [markdown]
# # Q1. Install python and understand the difference between scripting mode and interactive mode in IDLE.
#
# Explanation:
#
# *Interactive mode* : runs one statement at a time and shows immediate output.
#
# *Scripting mode* : run saved *.py* files, useful for larger programs and reuse.

# %%
import sys

print("Python is installed. ")
print("version:", sys.version)
# Out:
# Python is installed.
# version: 3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# # Q2. write python programs to print strings in the given manner.

# %%
# 2(a)

print("hello Everyone !!!")

# 2(b)

print("hello")
print("world")

# 2(c)
print("hello\nworld")

# 2(d)
print("rohit`s date of birth is 12/12/2000")
# Out:
# hello Everyone !!!
# hello
# world
# hello
# world
# rohit`s date of birth is 12/12/2000

# %% [markdown]
# # Q3. Declare a string variable called x and assign it the value *hello*. Print the value of x.

# %%
x="hello"
print(x)
# Out:
# hello

# %% [markdown]
# # Q4.Take different types and print values using the *print()* function.

# %%
integer_value = 10 
float_value = 3.14
string_value = "python"
boolean_value = True
list_value = [1,2,3,4,5]

print("integer_value:", integer_value)
print("float_value:", float_value)
print("string_value:", string_value)
print("boolean_value:", boolean_value)
print("list_value:", list_value)
# Out:
# integer_value: 10
# float_value: 3.14
# string_value: python
# boolean_value: True
# list_value: [1, 2, 3, 4, 5]

# %% [markdown]
# # Q5. Take two variables *a* and *b*. Assign your first name and last name. Print your full name by adding both.

# %%
a="shaurya"
b="benjwal"
full_name = a + " " + b
print("full_name:", full_name)
# Out:
# full_name: shaurya benjwal

# %% [markdown]
# # Q6. Declare first name, last name, and nickname. Print as: *FirstName (Nickname) lastname*.

# %%
first_name = "shaurya"
last_name = "benjwal"
nick_name = "nanu"

print(f"{first_name} {nick_name} {last_name}")
# Out:
# shaurya nanu benjwal

# %% [markdown]
# # Q7. Declare and assign suitable variables, then print the details in the required format.

# %%
name ="shaurya benjwal"
SAP_ID = "590028986"
dob = "6 oct 2006"
address_line1="UPES"
address_line2="bidholi Campus"
pincode = "248007"
programming = "data science"
semester = 2

print("name:",name)
print("SAP_ID:",SAP_ID)
print("dob:",dob)
print("address_line1:", address_line1)
print("address_line2:, address_line2")
# Out:
# name: shaurya benjwal
# SAP_ID: 590028986
# dob: 6 oct 2006
# address_line1: UPES
# address_line2:, address_line2
