# %% [markdown]
# # **NAME : SHAURYA BENJWAL**
# *SAP_ID: 590028986*
#
# *EXPERIMENT 6: Lists, Tuples, Dictionary*

# %% [markdown]
# # Q1. Scan *n* value in range *0-3* and print number of times each value has occured.

# %%
value = [0,1,2,3,2,1,0,3,3,2]
value = [0: 0,1: 0,2: 0,3:0]
for value in values:
    if value in counts:
        count[value] += 1

for key in counts:
    print(f"{key} occurred {counts[key]} time(s)")
# Out:
#   Cell In[1], line 2
#     value = [0: 0,1: 0,2: 0,3:0]
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Q2. *Create a tuple of numeric values and find average.*

# %%
numbers = (12, 25, 30, 18, 15)
average = sum(numbers) / len(numbers)
print("Tuple:", numbers)
print("Average:", average)
# Out:
# Tuple: (12, 25, 30, 18, 15)
# Average: 20.0

# %% [markdown]
# # Q3. *Input scores of students and print runner-up above.*

# %%
scores = [2, 3, 6, 6, 5]
unique_scores = sorted(set(scores), reverse=True)
runner_up = unique_scores[1]
print("Runner-up score:", runner_up)
# Out:
# Runner-up score: 5

# %% [markdown]
# # Q4. *Create a dictionary of persons where key is name and value is city, then:*
#
# * Display all names.
#
# * Display all city names.
#
# * Display student names with cities.
#
# * Count number of students in each city.

# %%
students = {
    "Aman": "Dehradun",
    "Riya": "Delhi",
    "Vikas": "Dehradun",
    "Neha": "Mumbai",
}

print("All names:", list(students.keys()))
print("All city names:", list(students.values()))

print("\nStudent and city details:")
for name, city in students.items():
    print(f"{name} -> {city}")

city_count = {}
for city in students.values():
    city_count[city] = city_count.get(city, 0) + 1

print("\nCount in each city:")
for city, count in city_count.items():
    print(f"{city}: {count}")
# Out:
# All names: ['Aman', 'Riya', 'Vikas', 'Neha']
# All city names: ['Dehradun', 'Delhi', 'Dehradun', 'Mumbai']
#
# Student and city details:
# Aman -> Dehradun
# Riya -> Delhi
# Vikas -> Dehradun
# Neha -> Mumbai
#
# Count in each city:
# Dehradun: 2
# Delhi: 1
# Mumbai: 1

# %% [markdown]
# # Q5. *Store details of movies and perform:*
#
# * Print all movie details.
#
# * Display movies released before 2015.
#
# * Print movies that made a profit.
#
# * Print movies by a particular director.

# %%
movies = [
    {"name": "Movie A", "year": 2012, "director": "Raj Mehra", "cost": 50, "collection": 80},
    {"name": "Movie B", "year": 2018, "director": "Anil Verma", "cost": 70, "collection": 65},
    {"name": "Movie C", "year": 2010, "director": "Raj Mehra", "cost": 40, "collection": 55},
]

print("All movie details:")
for movie in movies:
    print(movie)

print("\nMovies released before 2015:")
for movie in movies:
    if movie["year"] < 2015:
        print(movie["name"])

print("\nMovies that made profit:")
for movie in movies:
    if movie["collection"] > movie["cost"]:
        print(movie["name"])

search_director = "Raj Mehra"
print(f"\nMovies directed by {search_director}:")
for movie in movies:
    if movie["director"].lower() == search_director.lower():
        print(movie["name"])
# Out:
# All movie details:
# {'name': 'Movie A', 'year': 2012, 'director': 'Raj Mehra', 'cost': 50, 'collection': 80}
# {'name': 'Movie B', 'year': 2018, 'director': 'Anil Verma', 'cost': 70, 'collection': 65}
# {'name': 'Movie C', 'year': 2010, 'director': 'Raj Mehra', 'cost': 40, 'collection': 55}
#
# Movies released before 2015:
# Movie A
# Movie C
#
# Movies that made profit:
# Movie A
# Movie C
#
# Movies directed by Raj Mehra:
# Movie A
# Movie C
